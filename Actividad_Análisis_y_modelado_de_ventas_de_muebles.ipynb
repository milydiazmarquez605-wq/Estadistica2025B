# %% [markdown]
# <a href="https://colab.research.google.com/github/milydiazmarquez605-wq/Estadistica2025B/blob/main/Actividad_An%C3%A1lisis_y_modelado_de_ventas_de_muebles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/milydiazmarquez605-wq/Estadistica2025B/refs/heads/main/Furniture.csv"

df=pd.read_csv(url)

#a) Inspección y Limpieza de Datos
df = df.dropna()

df
# Out:
#            price        cost  sales  profit_margin  inventory  \
# 0     218.543053  181.610932     40      16.899243        105
# 1     477.821438  385.033827      7      19.418888        192
# 2     379.397274  276.736765     32      27.058842         59
# 3     319.396318  281.841334     48      11.758114         45
# 4     120.208388   69.743681     19      41.981019         35
# ...          ...         ...    ...            ...        ...
# 2495  271.546466  233.247261      8      14.104107        102
# 2496  309.775563  169.680310     24      45.224760          9
# 2497  439.509716  277.390903     48      36.886286        127
# 2498  491.332705  405.987306     38      17.370185          6
# 2499  233.412894  172.474611      6      26.107505         55
#
#       discount_percentage  delivery_days category material  color  location  \
# 0               27.796433              9      Bed  Plastic    Red     Rural
# 1               26.943715              6    Chair    Glass   Blue     Rural
# 2               21.948130              2    Table    Metal  Black  Suburban
# 3               11.009944              2    Table    Glass  Green     Rural
# 4                3.183763              9    Chair    Glass  Brown     Rural
# ...                   ...            ...      ...      ...    ...       ...
# 2495             9.789608              9    Chair    Metal  White  Suburban
# 2496            21.835025              8      Bed    Glass    Red     Urban
# 2497             2.817299              6     Desk   Fabric    Red     Rural
# 2498            19.781256              4     Desk    Metal  Black  Suburban
# 2499             9.502415              9     Desk    Glass  Green     Urban
#
#       season store_type   brand       revenue
# 0     Spring     Online  BrandA   3949.165238
# 1     Summer     Online  BrandD  -3521.002258
# 2       Fall     Online  BrandD  14285.560219
# 3     Summer     Retail  BrandD  12261.073703
# 4       Fall     Online  BrandD  -4588.255733
# ...      ...        ...     ...           ...
# 2495    Fall     Retail  BrandB  -3351.943350
# 2496  Summer     Retail  BrandD   -445.621346
# 2497  Summer     Online  BrandD  25809.096038
# 2498    Fall     Retail  BrandA  18963.246944
# 2499    Fall     Online  BrandC  -1692.339628
#
# [2500 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['price', 'cost', 'sales', 'profit_margin', 'inventory',
#        'discount_percentage', 'delivery_days', 'category', 'material', 'color',
#        'location', 'season', 'store_type', 'brand', 'revenue'],
#       dtype='object')

# %%
df.columns = ['precio', 'costo', 'ventas','margen_beneficio','inventario','porcentaje_descuento','dias_de_entrega','categoria','material','color','ubicacion','temporada','tipo_de_tienda','marca','ingresos']

df
# Out:
#           precio       costo  ventas  margen_beneficio  inventario  \
# 0     218.543053  181.610932      40         16.899243         105
# 1     477.821438  385.033827       7         19.418888         192
# 2     379.397274  276.736765      32         27.058842          59
# 3     319.396318  281.841334      48         11.758114          45
# 4     120.208388   69.743681      19         41.981019          35
# ...          ...         ...     ...               ...         ...
# 2495  271.546466  233.247261       8         14.104107         102
# 2496  309.775563  169.680310      24         45.224760           9
# 2497  439.509716  277.390903      48         36.886286         127
# 2498  491.332705  405.987306      38         17.370185           6
# 2499  233.412894  172.474611       6         26.107505          55
#
#       porcentaje_descuento  dias_de_entrega categoria material  color  \
# 0                27.796433                9       Bed  Plastic    Red
# 1                26.943715                6     Chair    Glass   Blue
# 2                21.948130                2     Table    Metal  Black
# 3                11.009944                2     Table    Glass  Green
# 4                 3.183763                9     Chair    Glass  Brown
# ...                    ...              ...       ...      ...    ...
# 2495              9.789608                9     Chair    Metal  White
# 2496             21.835025                8       Bed    Glass    Red
# 2497              2.817299                6      Desk   Fabric    Red
# 2498             19.781256                4      Desk    Metal  Black
# 2499              9.502415                9      Desk    Glass  Green
#
#      ubicacion temporada tipo_de_tienda   marca      ingresos
# 0        Rural    Spring         Online  BrandA   3949.165238
# 1        Rural    Summer         Online  BrandD  -3521.002258
# 2     Suburban      Fall         Online  BrandD  14285.560219
# 3        Rural    Summer         Retail  BrandD  12261.073703
# 4        Rural      Fall         Online  BrandD  -4588.255733
# ...        ...       ...            ...     ...           ...
# 2495  Suburban      Fall         Retail  BrandB  -3351.943350
# 2496     Urban    Summer         Retail  BrandD   -445.621346
# 2497     Rural    Summer         Online  BrandD  25809.096038
# 2498  Suburban      Fall         Retail  BrandA  18963.246944
# 2499     Urban      Fall         Online  BrandC  -1692.339628
#
# [2500 rows x 15 columns]

# %%
df['categoria'].unique()
# Out:
# array(['Bed', 'Chair', 'Table', 'Sofa', 'Desk'], dtype=object)

# %%
df['material'].unique()
# Out:
# array(['Plastic', 'Glass', 'Metal', 'Wood', 'Fabric'], dtype=object)

# %%
df['color'].unique()
# Out:
# array(['Red', 'Blue', 'Black', 'Green', 'Brown', 'White'], dtype=object)

# %%
df['ubicacion'].unique()
# Out:
# array(['Rural', 'Suburban', 'Urban'], dtype=object)

# %%
df['temporada'].unique()
# Out:
# array(['Spring', 'Summer', 'Fall', 'Winter'], dtype=object)

# %%
df['tipo_de_tienda'].unique()
# Out:
# array(['Online', 'Retail'], dtype=object)

# %%
df['marca'].unique()
# Out:
# array(['BrandA', 'BrandD', 'BrandB', 'BrandC'], dtype=object)

# %%
#b) Variables Categóricas y Balanceo
import matplotlib.pyplot as plt

categorical_cols = df.select_dtypes(include=['object', 'category']).columns
print(categorical_cols)

for col in categorical_cols:
    fig, ax = plt.subplots(figsize=(5, 5))

    df[col].value_counts(dropna=False).plot.pie(
        autopct='%1.1f%%',
        ax=ax,
        shadow=False,
        textprops={'fontsize': 12}
    )
    ax.set_title(f'Gráfico de pastel para la variable "{col}"', fontsize=12)
    ax.set_ylabel('')

    plt.tight_layout()
    plt.show()
# Out:
# Index(['categoria', 'material', 'color', 'ubicacion', 'temporada',
#        'tipo_de_tienda', 'marca'],
#       dtype='object')

# %%
#c) Modelo ANOVA
from statsmodels.formula.api import ols
import statsmodels.api as sm
# Y ~ X
modelo_lineal = ols('precio ~ costo + ventas + margen_beneficio + inventario + porcentaje_descuento + dias_de_entrega + C(categoria) + C(material) + C(color) + C(ubicacion) + C(temporada) + C(tipo_de_tienda) + C(marca) + ingresos', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                           df        sum_sq       mean_sq             F  \
# C(categoria)             4.0  9.657745e+04  2.414436e+04     51.554198
# C(material)              4.0  8.895205e+04  2.223801e+04     47.483664
# C(color)                 5.0  3.360018e+04  6.720036e+03     14.348941
# C(ubicacion)             2.0  6.284114e+04  3.142057e+04     67.090703
# C(temporada)             3.0  3.940800e+04  1.313600e+04     28.048617
# C(tipo_de_tienda)        1.0  6.042131e+02  6.042131e+02      1.290145
# C(marca)                 3.0  3.198871e+04  1.066290e+04     22.767941
# costo                    1.0  3.693319e+07  3.693319e+07  78861.501579
# ventas                   1.0  2.565956e+03  2.565956e+03      5.478952
# margen_beneficio         1.0  4.363054e+06  4.363054e+06   9316.200385
# inventario               1.0  1.317049e+02  1.317049e+02      0.281223
# porcentaje_descuento     1.0  2.123721e+02  2.123721e+02      0.453467
# dias_de_entrega          1.0  7.362028e+02  7.362028e+02      1.571975
# ingresos                 1.0  8.246114e+03  8.246114e+03     17.607496
# Residual              2470.0  1.156774e+06  4.683297e+02           NaN
#
#                             PR(>F)
# C(categoria)          9.439574e-42
# C(material)           1.642059e-38
# C(color)              7.101209e-14
# C(ubicacion)          4.234123e-29
# C(temporada)          7.846721e-18
# C(tipo_de_tienda)     2.561315e-01
# C(marca)              1.545171e-14
# costo                 0.000000e+00
# ventas                1.932597e-02
# margen_beneficio      0.000000e+00
# inventario            5.959487e-01
# porcentaje_descuento  5.007560e-01
# dias_de_entrega       2.100390e-01
# ingresos              2.811067e-05
# Residual                       NaN

# %%
#d) Test de Tukey y codificación
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(
    endog=df['precio'],
    groups=df['categoria'],          # Variable categorica
    alpha=nivel_de_significancia) # nivel de significancia

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="categoria", xlabel="precio")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#    Bed  Chair  12.1689 0.5927 -10.6785 35.0163  False
#    Bed   Desk  18.7634 0.1632  -4.0391 41.5659  False
#    Bed   Sofa  13.6787 0.4802  -9.2721 36.6295  False
#    Bed  Table   14.382 0.4049  -8.0828 36.8467  False
#  Chair   Desk   6.5945 0.9318 -16.0199  29.209  False
#  Chair   Sofa   1.5098 0.9998 -21.2542 24.2738  False
#  Chair  Table   2.2131 0.9988 -20.0608 24.4869  False
#   Desk   Sofa  -5.0847 0.9734 -27.8036 17.6342  False
#   Desk  Table  -4.3815 0.9834 -26.6093 17.8463  False
#   Sofa  Table   0.7032    1.0 -21.6766 23.0831  False
# -----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["categoria"] = df["categoria"].map({"Bed": 0, "Chair":1, "Table":1, "Sofa":1, "Desk":2})
df
# Out:
#           precio       costo  ventas  margen_beneficio  inventario  \
# 0     218.543053  181.610932      40         16.899243         105
# 1     477.821438  385.033827       7         19.418888         192
# 2     379.397274  276.736765      32         27.058842          59
# 3     319.396318  281.841334      48         11.758114          45
# 4     120.208388   69.743681      19         41.981019          35
# ...          ...         ...     ...               ...         ...
# 2495  271.546466  233.247261       8         14.104107         102
# 2496  309.775563  169.680310      24         45.224760           9
# 2497  439.509716  277.390903      48         36.886286         127
# 2498  491.332705  405.987306      38         17.370185           6
# 2499  233.412894  172.474611       6         26.107505          55
#
#       porcentaje_descuento  dias_de_entrega  categoria material  color  \
# 0                27.796433                9          0  Plastic    Red
# 1                26.943715                6          1    Glass   Blue
# 2                21.948130                2          1    Metal  Black
# 3                11.009944                2          1    Glass  Green
# 4                 3.183763                9          1    Glass  Brown
# ...                    ...              ...        ...      ...    ...
# 2495              9.789608                9          1    Metal  White
# 2496             21.835025                8          0    Glass    Red
# 2497              2.817299                6          2   Fabric    Red
# 2498             19.781256                4          2    Metal  Black
# 2499              9.502415                9          2    Glass  Green
#
#      ubicacion temporada tipo_de_tienda   marca      ingresos
# 0        Rural    Spring         Online  BrandA   3949.165238
# 1        Rural    Summer         Online  BrandD  -3521.002258
# 2     Suburban      Fall         Online  BrandD  14285.560219
# 3        Rural    Summer         Retail  BrandD  12261.073703
# 4        Rural      Fall         Online  BrandD  -4588.255733
# ...        ...       ...            ...     ...           ...
# 2495  Suburban      Fall         Retail  BrandB  -3351.943350
# 2496     Urban    Summer         Retail  BrandD   -445.621346
# 2497     Rural    Summer         Online  BrandD  25809.096038
# 2498  Suburban      Fall         Retail  BrandA  18963.246944
# 2499     Urban      Fall         Online  BrandC  -1692.339628
#
# [2500 rows x 15 columns]

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(
    endog=df['precio'], # Variable de respuesta
    groups=df['material'],          # Variable categorica
    alpha=nivel_de_significancia) # nivel de significancia

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="material", xlabel="precio")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1  group2 meandiff p-adj   lower    upper  reject
# -------------------------------------------------------
#  Fabric   Glass -16.3299  0.306 -39.5288  6.8691  False
#  Fabric   Metal -14.3415 0.4279  -37.237  8.5539  False
#  Fabric Plastic -15.6566 0.3534 -38.9449  7.6316  False
#  Fabric    Wood  -8.0018 0.8757 -30.9072 14.9035  False
#   Glass   Metal   1.9883 0.9992 -20.2933 24.2699  False
#   Glass Plastic   0.6733    1.0 -22.0118 23.3583  False
#   Glass    Wood   8.3281 0.8463 -13.9638 30.6199  False
#   Metal Plastic  -1.3151 0.9999 -23.6896 21.0594  False
#   Metal    Wood   6.3397 0.9343  -15.636 28.3155  False
# Plastic    Wood   7.6548 0.8839 -14.7299 30.0395  False
# -------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["material"] = df["material"].map({"Plastic": 0, "Metal":0, "Glass":0, "Wood":1, "Fabric":2 })
df
# Out:
#           precio       costo  ventas  margen_beneficio  inventario  \
# 0     218.543053  181.610932      40         16.899243         105
# 1     477.821438  385.033827       7         19.418888         192
# 2     379.397274  276.736765      32         27.058842          59
# 3     319.396318  281.841334      48         11.758114          45
# 4     120.208388   69.743681      19         41.981019          35
# ...          ...         ...     ...               ...         ...
# 2495  271.546466  233.247261       8         14.104107         102
# 2496  309.775563  169.680310      24         45.224760           9
# 2497  439.509716  277.390903      48         36.886286         127
# 2498  491.332705  405.987306      38         17.370185           6
# 2499  233.412894  172.474611       6         26.107505          55
#
#       porcentaje_descuento  dias_de_entrega  categoria  material  color  \
# 0                27.796433                9          0         0    Red
# 1                26.943715                6          1         0   Blue
# 2                21.948130                2          1         0  Black
# 3                11.009944                2          1         0  Green
# 4                 3.183763                9          1         0  Brown
# ...                    ...              ...        ...       ...    ...
# 2495              9.789608                9          1         0  White
# 2496             21.835025                8          0         0    Red
# 2497              2.817299                6          2         2    Red
# 2498             19.781256                4          2         0  Black
# 2499              9.502415                9          2         0  Green
#
#      ubicacion temporada tipo_de_tienda   marca      ingresos
# 0        Rural    Spring         Online  BrandA   3949.165238
# 1        Rural    Summer         Online  BrandD  -3521.002258
# 2     Suburban      Fall         Online  BrandD  14285.560219
# 3        Rural    Summer         Retail  BrandD  12261.073703
# 4        Rural      Fall         Online  BrandD  -4588.255733
# ...        ...       ...            ...     ...           ...
# 2495  Suburban      Fall         Retail  BrandB  -3351.943350
# 2496     Urban    Summer         Retail  BrandD   -445.621346
# 2497     Rural    Summer         Online  BrandD  25809.096038
# 2498  Suburban      Fall         Retail  BrandA  18963.246944
# 2499     Urban      Fall         Online  BrandC  -1692.339628
#
# [2500 rows x 15 columns]

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(
    endog=df['precio'], # Variable de respuesta
    groups=df['color'],          # Variable categorica
    alpha=nivel_de_significancia) # nivel de significancia

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="color", xlabel="precio")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#  Black   Blue  -6.6588  0.977 -32.3394 19.0218  False
#  Black  Brown  -6.3939 0.9805 -31.9909 19.2031  False
#  Black  Green  -6.9891 0.9717 -32.7037 18.7254  False
#  Black    Red  -0.2042    1.0 -25.5921 25.1836  False
#  Black  White   0.4321    1.0 -24.8326 25.6967  False
#   Blue  Brown   0.2649    1.0 -26.0356 26.5654  False
#   Blue  Green  -0.3304    1.0 -26.7452 26.0845  False
#   Blue    Red   6.4546 0.9813 -19.6424 32.5516  False
#   Blue  White   7.0908 0.9712 -18.8863  33.068  False
#  Brown  Green  -0.5952    1.0 -26.9289 25.7384  False
#  Brown    Red   6.1897 0.9843  -19.825 32.2045  False
#  Brown  White    6.826 0.9753 -19.0685 32.7205  False
#  Green    Red   6.7849 0.9769 -19.3454 32.9153  False
#  Green  White   7.4212 0.9651 -18.5895 33.4319  False
#    Red  White   0.6363    1.0 -25.0515 26.3241  False
# -----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["color"] = df["color"].map({"Green": 0, "Brown":0, "Blue":0, "Black":1, "White":1, "Red":1})
df
# Out:
#           precio       costo  ventas  margen_beneficio  inventario  \
# 0     218.543053  181.610932      40         16.899243         105
# 1     477.821438  385.033827       7         19.418888         192
# 2     379.397274  276.736765      32         27.058842          59
# 3     319.396318  281.841334      48         11.758114          45
# 4     120.208388   69.743681      19         41.981019          35
# ...          ...         ...     ...               ...         ...
# 2495  271.546466  233.247261       8         14.104107         102
# 2496  309.775563  169.680310      24         45.224760           9
# 2497  439.509716  277.390903      48         36.886286         127
# 2498  491.332705  405.987306      38         17.370185           6
# 2499  233.412894  172.474611       6         26.107505          55
#
#       porcentaje_descuento  dias_de_entrega  categoria  material  color  \
# 0                27.796433                9          0         0      1
# 1                26.943715                6          1         0      0
# 2                21.948130                2          1         0      1
# 3                11.009944                2          1         0      0
# 4                 3.183763                9          1         0      0
# ...                    ...              ...        ...       ...    ...
# 2495              9.789608                9          1         0      1
# 2496             21.835025                8          0         0      1
# 2497              2.817299                6          2         2      1
# 2498             19.781256                4          2         0      1
# 2499              9.502415                9          2         0      0
#
#      ubicacion temporada tipo_de_tienda   marca      ingresos
# 0        Rural    Spring         Online  BrandA   3949.165238
# 1        Rural    Summer         Online  BrandD  -3521.002258
# 2     Suburban      Fall         Online  BrandD  14285.560219
# 3        Rural    Summer         Retail  BrandD  12261.073703
# 4        Rural      Fall         Online  BrandD  -4588.255733
# ...        ...       ...            ...     ...           ...
# 2495  Suburban      Fall         Retail  BrandB  -3351.943350
# 2496     Urban    Summer         Retail  BrandD   -445.621346
# 2497     Rural    Summer         Online  BrandD  25809.096038
# 2498  Suburban      Fall         Retail  BrandA  18963.246944
# 2499     Urban      Fall         Online  BrandC  -1692.339628
#
# [2500 rows x 15 columns]

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(
    endog=df['precio'], # Variable de respuesta
    groups=df['ubicacion'],          # Variable categorica
    alpha=nivel_de_significancia) # nivel de significancia

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="ubicacion", xlabel="precio")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
#  group1   group2  meandiff p-adj   lower    upper  reject
# ---------------------------------------------------------
#    Rural Suburban   3.8272 0.8179 -11.0323 18.6867  False
#    Rural    Urban  -8.4754   0.38  -23.448  6.4971  False
# Suburban    Urban -12.3026 0.1441 -27.6331  3.0279  False
# ---------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["ubicacion"] = df["ubicacion"].map({"Urban": 0, "Rural":1, "Suburban":2})
df
# Out:
#           precio       costo  ventas  margen_beneficio  inventario  \
# 0     218.543053  181.610932      40         16.899243         105
# 1     477.821438  385.033827       7         19.418888         192
# 2     379.397274  276.736765      32         27.058842          59
# 3     319.396318  281.841334      48         11.758114          45
# 4     120.208388   69.743681      19         41.981019          35
# ...          ...         ...     ...               ...         ...
# 2495  271.546466  233.247261       8         14.104107         102
# 2496  309.775563  169.680310      24         45.224760           9
# 2497  439.509716  277.390903      48         36.886286         127
# 2498  491.332705  405.987306      38         17.370185           6
# 2499  233.412894  172.474611       6         26.107505          55
#
#       porcentaje_descuento  dias_de_entrega  categoria  material  color  \
# 0                27.796433                9          0         0      1
# 1                26.943715                6          1         0      0
# 2                21.948130                2          1         0      1
# 3                11.009944                2          1         0      0
# 4                 3.183763                9          1         0      0
# ...                    ...              ...        ...       ...    ...
# 2495              9.789608                9          1         0      1
# 2496             21.835025                8          0         0      1
# 2497              2.817299                6          2         2      1
# 2498             19.781256                4          2         0      1
# 2499              9.502415                9          2         0      0
#
#       ubicacion temporada tipo_de_tienda   marca      ingresos
# 0             1    Spring         Online  BrandA   3949.165238
# 1             1    Summer         Online  BrandD  -3521.002258
# 2             2      Fall         Online  BrandD  14285.560219
# 3             1    Summer         Retail  BrandD  12261.073703
# 4             1      Fall         Online  BrandD  -4588.255733
# ...         ...       ...            ...     ...           ...
# 2495          2      Fall         Retail  BrandB  -3351.943350
# 2496          0    Summer         Retail  BrandD   -445.621346
# 2497          1    Summer         Online  BrandD  25809.096038
# 2498          2      Fall         Retail  BrandA  18963.246944
# 2499          0      Fall         Online  BrandC  -1692.339628
#
# [2500 rows x 15 columns]

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(
    endog=df['precio'], # Variable de respuesta
    groups=df['temporada'],          # Variable categorica
    alpha=nivel_de_significancia) # nivel de significancia

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="temporada", xlabel="precio")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#   Fall Spring  -1.5262 0.9969 -20.4601 17.4077  False
#   Fall Summer  -5.1699 0.8999 -24.3524 14.0126  False
#   Fall Winter  -9.8403 0.5272 -28.4952  8.8146  False
# Spring Summer  -3.6437 0.9632 -23.0976 15.8102  False
# Spring Winter  -8.3141 0.6717  -27.248 10.6198  False
# Summer Winter  -4.6704 0.9238 -23.8529 14.5121  False
# -----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["temporada"] = df["temporada"].map({"Winter": 0, "Summer":1, "Spring":2, "Fall":3,})
df
# Out:
#           precio       costo  ventas  margen_beneficio  inventario  \
# 0     218.543053  181.610932      40         16.899243         105
# 1     477.821438  385.033827       7         19.418888         192
# 2     379.397274  276.736765      32         27.058842          59
# 3     319.396318  281.841334      48         11.758114          45
# 4     120.208388   69.743681      19         41.981019          35
# ...          ...         ...     ...               ...         ...
# 2495  271.546466  233.247261       8         14.104107         102
# 2496  309.775563  169.680310      24         45.224760           9
# 2497  439.509716  277.390903      48         36.886286         127
# 2498  491.332705  405.987306      38         17.370185           6
# 2499  233.412894  172.474611       6         26.107505          55
#
#       porcentaje_descuento  dias_de_entrega  categoria  material  color  \
# 0                27.796433                9          0         0      1
# 1                26.943715                6          1         0      0
# 2                21.948130                2          1         0      1
# 3                11.009944                2          1         0      0
# 4                 3.183763                9          1         0      0
# ...                    ...              ...        ...       ...    ...
# 2495              9.789608                9          1         0      1
# 2496             21.835025                8          0         0      1
# 2497              2.817299                6          2         2      1
# 2498             19.781256                4          2         0      1
# 2499              9.502415                9          2         0      0
#
#       ubicacion  temporada tipo_de_tienda   marca      ingresos
# 0             1          2         Online  BrandA   3949.165238
# 1             1          1         Online  BrandD  -3521.002258
# 2             2          3         Online  BrandD  14285.560219
# 3             1          1         Retail  BrandD  12261.073703
# 4             1          3         Online  BrandD  -4588.255733
# ...         ...        ...            ...     ...           ...
# 2495          2          3         Retail  BrandB  -3351.943350
# 2496          0          1         Retail  BrandD   -445.621346
# 2497          1          1         Online  BrandD  25809.096038
# 2498          2          3         Retail  BrandA  18963.246944
# 2499          0          3         Online  BrandC  -1692.339628
#
# [2500 rows x 15 columns]

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(
    endog=df['precio'], # Variable de respuesta
    groups=df['marca'],          # Variable categorica
    alpha=nivel_de_significancia) # nivel de significancia

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="marca", xlabel="precio")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
# BrandA BrandB   0.0433    1.0 -19.1132 19.1998  False
# BrandA BrandC   7.7988 0.7071 -10.9153 26.5129  False
# BrandA BrandD   6.0373 0.8447 -12.8735  24.948  False
# BrandB BrandC   7.7555 0.7268 -11.4433 26.9543  False
# BrandB BrandD   5.9939 0.8569 -13.3967 25.3846  False
# BrandC BrandD  -1.7615 0.9952 -20.7152 17.1921  False
# -----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["marca"] = df["marca"].map({"BrandB": 0, "BrandA":0, "BrandD":1, "BrandC":2, })
df
# Out:
#           precio       costo  ventas  margen_beneficio  inventario  \
# 0     218.543053  181.610932      40         16.899243         105
# 1     477.821438  385.033827       7         19.418888         192
# 2     379.397274  276.736765      32         27.058842          59
# 3     319.396318  281.841334      48         11.758114          45
# 4     120.208388   69.743681      19         41.981019          35
# ...          ...         ...     ...               ...         ...
# 2495  271.546466  233.247261       8         14.104107         102
# 2496  309.775563  169.680310      24         45.224760           9
# 2497  439.509716  277.390903      48         36.886286         127
# 2498  491.332705  405.987306      38         17.370185           6
# 2499  233.412894  172.474611       6         26.107505          55
#
#       porcentaje_descuento  dias_de_entrega  categoria  material  color  \
# 0                27.796433                9          0         0      1
# 1                26.943715                6          1         0      0
# 2                21.948130                2          1         0      1
# 3                11.009944                2          1         0      0
# 4                 3.183763                9          1         0      0
# ...                    ...              ...        ...       ...    ...
# 2495              9.789608                9          1         0      1
# 2496             21.835025                8          0         0      1
# 2497              2.817299                6          2         2      1
# 2498             19.781256                4          2         0      1
# 2499              9.502415                9          2         0      0
#
#       ubicacion  temporada tipo_de_tienda  marca      ingresos
# 0             1          2         Online      0   3949.165238
# 1             1          1         Online      1  -3521.002258
# 2             2          3         Online      1  14285.560219
# 3             1          1         Retail      1  12261.073703
# 4             1          3         Online      1  -4588.255733
# ...         ...        ...            ...    ...           ...
# 2495          2          3         Retail      0  -3351.943350
# 2496          0          1         Retail      1   -445.621346
# 2497          1          1         Online      1  25809.096038
# 2498          2          3         Retail      0  18963.246944
# 2499          0          3         Online      2  -1692.339628
#
# [2500 rows x 15 columns]

# %%
#e) Mapa de calor y multicolinealidad
import seaborn as sns
import matplotlib.pyplot as plt

# Seleccion de variables numericas para la correlacion
numerical_df = df.select_dtypes(include=['float64', 'int64'])

correlation_matrix = numerical_df.corr()
plt.figure(figsize=(8, 8))
sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            fmt=".2f",
            square=True,
            center=0,
            cbar_kws={"shrink": .8})
plt.title('Mapa de Calor de la Matriz de Correlación')
plt.show()

# %%
x = df[["costo","ventas" , "margen_beneficio" , "inventario", "porcentaje_descuento", "dias_de_entrega","categoria","material","color","ubicacion","temporada","marca","ingresos"]]
y = df["precio"]

# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)
# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')

# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')

# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales = modelo.resid
plt.figure()
plt.scatter(x["costo"], residuales, color = 'pink')
plt.xlabel('costo')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["ventas"], residuales, color = 'pink')
plt.xlabel('ventas')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["margen_beneficio"], residuales, color = 'pink')
plt.xlabel('margen_beneficio')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["inventario"], residuales, color = 'pink')
plt.xlabel('inventario')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["porcentaje_descuento"], residuales, color = 'pink')
plt.xlabel('porcentaje_descuento')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["dias_de_entrega"], residuales, color = 'pink')
plt.xlabel('dias_de_entrega')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["categoria"], residuales, color = 'pink')
plt.xlabel('categoria')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["material"], residuales, color = 'pink')
plt.xlabel('material')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["color"], residuales, color = 'pink')
plt.xlabel('color')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["ubicacion"], residuales, color = 'pink')
plt.xlabel('ubicacion')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["temporada"], residuales, color = 'pink')
plt.xlabel('temporada')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["marca"], residuales, color = 'pink')
plt.xlabel('marca')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

residuales = modelo.resid
plt.figure()
plt.scatter(x["marca"], residuales, color = 'pink')
plt.xlabel('marca')
plt.ylabel('precio')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)
# Out:
# Coeficiente de determinación:  0.9727
#
# Intervalo de confianza para b1 de  95%
#  1.3749 < b1 <  1.3955

# %%
df['venta_calculadas'] = yc
df
# Out:
#           precio       costo  ventas  margen_beneficio  inventario  \
# 0     218.543053  181.610932      40         16.899243         105
# 1     477.821438  385.033827       7         19.418888         192
# 2     379.397274  276.736765      32         27.058842          59
# 3     319.396318  281.841334      48         11.758114          45
# 4     120.208388   69.743681      19         41.981019          35
# ...          ...         ...     ...               ...         ...
# 2495  271.546466  233.247261       8         14.104107         102
# 2496  309.775563  169.680310      24         45.224760           9
# 2497  439.509716  277.390903      48         36.886286         127
# 2498  491.332705  405.987306      38         17.370185           6
# 2499  233.412894  172.474611       6         26.107505          55
#
#       porcentaje_descuento  dias_de_entrega  categoria  material  color  \
# 0                27.796433                9          0         0      1
# 1                26.943715                6          1         0      0
# 2                21.948130                2          1         0      1
# 3                11.009944                2          1         0      0
# 4                 3.183763                9          1         0      0
# ...                    ...              ...        ...       ...    ...
# 2495              9.789608                9          1         0      1
# 2496             21.835025                8          0         0      1
# 2497              2.817299                6          2         2      1
# 2498             19.781256                4          2         0      1
# 2499              9.502415                9          2         0      0
#
#       ubicacion  temporada tipo_de_tienda  marca      ingresos  \
# 0             1          2         Online      0   3949.165238
# 1             1          1         Online      1  -3521.002258
# 2             2          3         Online      1  14285.560219
# 3             1          1         Retail      1  12261.073703
# 4             1          3         Online      1  -4588.255733
# ...         ...        ...            ...    ...           ...
# 2495          2          3         Retail      0  -3351.943350
# 2496          0          1         Retail      1   -445.621346
# 2497          1          1         Online      1  25809.096038
# 2498          2          3         Retail      0  18963.246944
# 2499          0          3         Online      2  -1692.339628
#
#       venta_calculadas
# 0           204.762266
# 1           499.443614
# 2           383.707735
# 3           328.220530
# 4           146.535116
# ...                ...
# 2495        267.151769
# 2496        296.431720
# 2497        424.552213
# 2498        526.799978
# 2499        232.454429
#
# [2500 rows x 16 columns]

# %%
modelo.params
# Out:
# const                  -111.003636
# costo                     1.385214
# ventas                   -0.084644
# margen_beneficio          3.843706
# inventario                0.003771
# porcentaje_descuento      0.056998
# dias_de_entrega          -0.191226
# categoria                 1.645493
# material                  0.419736
# color                    -0.230492
# ubicacion                 0.252120
# temporada                 0.505080
# marca                     0.719948
# ingresos                  0.000338
# dtype: float64

# %%
x = df[["porcentaje_descuento", "categoria","material","color","ubicacion","temporada","marca"]]
y = df["precio"]

# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)
# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')

# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')
# Out:
# Coeficiente de determinación:  0.0083
#
# Intervalo de confianza para b1 de  95%
# -0.9565 < b1 <  0.2327
